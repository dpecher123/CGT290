# %%
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-20-e0e1492b7973> in <module>
# ----> 1 import numpy as np
#       2 import matplotlib.pyplot as plt
#
# ~\numpy\__init__.py in <module>
#     138
#     139     # Allow distributors to run custom init code
# --> 140     from . import _distributor_init
#     141
#     142     from . import core
#
# ~\numpy\_distributor_init.py in <module>
#      24                 # NOTE: would it change behavior to load ALL
#      25                 # DLLs at this path vs. the name restriction?
# ---> 26                 WinDLL(os.path.abspath(filename))
#      27                 DLL_filenames.append(filename)
#      28     if len(DLL_filenames) > 1:
#
# ~\Anaconda3\lib\ctypes\__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     362
#     363         if handle is None:
# ...

# %%
category_names = ['Strongly disagree', 'Disagree',
                  'Neutral', 'Agree', 'Strongly agree']
results = {
    'Question 1': [0, 4, 21, 64, 11],
    'Question 2': [0, 11, 21, 54, 14],
    'Question 3': [0, 7, 21, 57, 14]
    }
labels = list(results.keys())
data = np.array(list(results.values()))
data_cum = data.cumsum(axis=1)
category_colors = plt.get_cmap('RdYlGn')(np.linspace(0.15, 0.85, data.shape[1]))
fig, ax = plt.subplots(figsize=(9.2, 5))
ax.invert_yaxis()
ax.xaxis.set_visible(False)
ax.set_xlim(0, np.sum(data, axis=1).max())

for i, (colname, color) in enumerate(zip(category_names, category_colors)):
    widths = data[:, i]
    starts = data_cum[:, i] - widths
    ax.barh(labels, widths, left=starts, height=0.5, label=colname, color=color)
    xcenters = starts + widths / 2

    r, g, b, _ = color
    text_color = 'white' if r * g * b < 0.5 else 'darkgrey'
    for y, (x, c) in enumerate(zip(xcenters, widths)):
        ax.text(x, y, str(int(c)), ha='center', va='center', color=text_color)
    ax.legend(ncol=len(category_names), bbox_to_anchor=(0, 1), loc='lower left', fontsize='small')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-dffa22c1636d> in <module>
#       7     }
#       8 labels = list(results.keys())
# ----> 9 data = np.array(list(results.values()))
#      10 data_cum = data.cumsum(axis=1)
#      11 category_colors = plt.get_cmap('RdYlGn')(np.linspace(0.15, 0.85, data.shape[1]))
#
# NameError: name 'np' is not defined

# %% [markdown]
# ![summary.JPG](attachment:summary.JPG)

# %%
labels = ['Strongly Disagree', 'Disagree', 'Neutral', 'Agree', 'Strongly Agree']    sizes = [5, 9, 41, 40, 5]
colors = ['lightcoral', 'bisque', 'lightyellow', 'yellowgreen', 'darkgreen']
patches, texts = plt.pie(sizes, colors=colors, shadow=True, startangle=90)
plt.legend(patches, labels, loc="lower right")
plt.axis('equal')
plt.tight_layout()
plt.title("Question 1 Responses for LC Section")
plt.show()

# %% [markdown]
# ![Pie.JPG](attachment:Pie.JPG)

# %%
responses = ('4', '3', '2', '1')
means = [3.64, 3.74, 3.72, 1.69]
plt.barh(responses, means, align='center', color=['plum', 'moccasin', 'lightblue', 'mistyrose'])
plt.xlabel('Mean Value')
plt.ylabel('Question Number')
plt.title("Mean Value by Question for Combined Sections")
plt.text(1.57, 3, "1.64")
plt.text(3.62, 2, "3.72")
plt.text(3.64, 1, "3.74")
plt.text(3.54, 0, "3.64")
plt.show()

# %% [markdown]
# ![Bar.JPG](attachment:Bar.JPG)
